# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
data = np.random.randint(1,50,100)

# %%
data
# Out:
# array([27,  1, 13, 41,  8, 28, 41, 39, 32, 30, 46, 22, 40, 36,  8, 44, 49,
#        22, 29,  8, 10, 19, 42, 10,  5, 44,  5, 14, 26, 28, 43, 27, 17,  2,
#         5,  5, 10,  4, 18, 17, 20, 46,  9, 47, 36, 15, 33, 14, 45, 38,  4,
#        28,  4, 47, 19, 17, 17, 45, 45, 15, 48, 13, 20, 26, 34, 18, 10,  4,
#        25, 49, 34, 20, 41,  9, 43, 41, 27, 24,  6, 11, 45, 16, 20, 43, 48,
#        49, 41, 48,  7, 25, 36, 34, 42, 10,  5, 18, 47,  3, 40, 22])

# %% [markdown]
# ## HISTOGRAMA

# %%
plt.hist(data,bins=10,histtype='step')
plt.show()

# %% [markdown]
# ## BOXPLOT

# %%
plt.boxplot(data, vert = False, patch_artist=True, notch=True)
plt.show()

# %%
data = np.append(data,200)
plt.boxplot(data, vert = False, patch_artist=True, notch=True, showfliers=True)
plt.show()

# %%
data = np.append(data,200)
plt.boxplot(data, vert = False, patch_artist=True, notch=True, showfliers=False)
plt.show()

# %% [markdown]
# ## SCATTER
#
# Muesttra la relacion entre dos distinta variables

# %%
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
area = (30 * np.random.rand(N)) **2
colors = np.random.rand(N)

# %%
plt.scatter(x,y, s=area, c=colors, marker='p', alpha=0.5)
plt.show()
